# %% [markdown]
# # Task- 2

# %% [markdown]
# ## STOCK MARKET PREDICTION USING LSTM

# %% [markdown]
# ##### Anchal kapoor

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Data set with historical price information for 3 high growth stocks and bitcoin from May 2013 to May 2019. Basic analysis of returns and visualizations included.
#
# In this notebook, we will discover and explore data from the stock market, particularly some technology stocks (Apple, Amazon, Google, and Microsoft). We will learn how to use finance to get stock information, and visualize different aspects of it using Seaborn and Matplotlib. we will look at a few ways of analyzing the risk of a stock, based on its previous performance history. We will also be predicting future stock prices through a Long Short Term Memory (LSTM) method!

# %% [markdown]
# **Importing libraries**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np
import math 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
stock = pd.read_csv('global.csv')

# %%
stock.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
stock.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
#Checking for null values in dataset
stock.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
stock['Date'] = pd.to_datetime(stock['Date'])
stock.dtypes
# Out:
# Date                    datetime64[ns]
# Open                           float64
# High                           float64
# Low                            float64
# Last                           float64
# Close                          float64
# Total Trade Quantity             int64
# Turnover (Lacs)                float64
# dtype: object

# %%
stock = stock.sort_values('Date')
stock.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
plt.figure(figsize = (9,6))
plt.title(' TATA Global Stocks Closing Price')
plt.plot(stock['Close'],color='green')
plt.xlabel('Date',fontsize=15)
plt.ylabel('Close',fontsize=15)
# Out:
# Text(0, 0.5, 'Close')

# %%
data_close = stock.reset_index()['Close']
data_close.head()
# Out:
# 0    121.55
# 1    120.90
# 2    120.65
# 3    117.60
# 4    118.65
# Name: Close, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller

#Test for stationary
def test_stationary(timeseries):
    rolemean=timeseries.rolling(12).mean()
    rolestd=timeseries.rolling(12).std()
    plt.figure(figsize=(18,8))
    plt.grid('both')
    plt.plot(timeseries,color='blue',label='Orginal',linewidth=3)
    plt.plot(rolemean,color='red',label='Rolling Mean',linewidth=3)
    plt.plot(rolestd,color='green',label='Rolling Std',linewidth=3)
    plt.show()
    adft=adfuller(timeseries,autolag='AIC')
    output=pd.Series(adft[0:4],index=['Test Statistics','p-value','No of lags','No of observation used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key]=values
    print(output)    
test_stationary(data_close)
# Out:
# Test Statistics             -0.901358
# p-value                      0.787525
# No of lags                  16.000000
# No of observation used    2018.000000
# critical value (1%)         -3.433595
# critical value (5%)         -2.862973
# critical value (10%)        -2.567533
# dtype: float64

# %%
#scaler = MinMaxScaler(feature_range = (0, 1))
#data_close = scaler.fit_transform(np.array(data_close).reshape(-1, 1))

#Lets scale the data by using Min Max scaler
scaler = MinMaxScaler(feature_range = (0, 1))
data_close = scaler.fit_transform(np.array(data_close).reshape(-1, 1))

# %% [markdown]
# **Now Applying Train Test Split:**

# %%
train_size = int(len(data_close)*0.70)
test_size = len(data_close) - train_size
train, test = data_close[0 : train_size, :], data_close[train_size : len(data_close), :1]

# %% [markdown]
# **Pre-Processing The Dataset:**

# %%
def create_matrix(ds, time_step=1):
    dataX, dataY = [], []
    for i in range(len(ds)-time_step-1):
        a = ds[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(ds[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
step=100 
X_train, y_train = create_matrix(train, step)
X_test, y_test = create_matrix(test, step)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1323, 100) (1323,)
# (510, 100) (510,)

# %% [markdown]
# **LSTM Model**

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.1, epochs=77, batch_size=64, verbose=1, shuffle=True).history
# Out:
# Epoch 1/77
# 19/19 [==============================] - 19s 460ms/step - loss: 0.0093 - val_loss: 0.0021
# Epoch 2/77
# 19/19 [==============================] - 6s 295ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 3/77
# 19/19 [==============================] - 5s 287ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 4/77
# 19/19 [==============================] - 5s 281ms/step - loss: 9.2108e-04 - val_loss: 0.0012
# Epoch 5/77
# 19/19 [==============================] - 5s 284ms/step - loss: 8.6870e-04 - val_loss: 0.0013
# Epoch 6/77
# 19/19 [==============================] - 5s 286ms/step - loss: 8.4564e-04 - val_loss: 0.0011
# Epoch 7/77
# 19/19 [==============================] - 5s 289ms/step - loss: 8.3942e-04 - val_loss: 0.0012
# Epoch 8/77
# 19/19 [==============================] - 5s 284ms/step - loss: 8.0659e-04 - val_loss: 0.0011
# Epoch 9/77
# 19/19 [==============================] - 5s 281ms/step - loss: 7.9627e-04 - val_loss: 0.0010
# Epoch 10/77
# 19/19 [==============================] - 5s 281ms/step - loss: 7.7021e-04 - val_loss: 9.7956e-04
# Epoch 11/77
# 19/19 [==============================] - 5s 284ms/step - loss: 7.5351e-04 - val_loss: 9.4567e-04
# Epoch 12/77
# 19/19 [==============================] - 5s 284ms/step - loss: 7.3787e-04 - val_loss: 9.1852e-04
# Epoch 13/77
# 19/19 [==============================] - 5s 283ms/step - loss: 6.9854e-04 - val_loss: 8.7266e-04
# Epoch 14/77
# 19/19 [==============================] - 5s 278ms/step - loss: 6.8802e-04 - val_loss: 8.7840e-04
# Epoch 15/77
# 19/19 [==============================] - 5s 286ms/step - loss: 7.2127e-04 - val_loss: 8.0771e-04
# Epoch 16/77
# 19/19 [==============================] - 5s 269ms/step - loss: 6.8262e-04 - val_loss: 7.9888e-04
# Epoch 17/77
# 19/19 [==============================] - 5s 255ms/step - loss: 6.5273e-04 - val_loss: 7.6858e-04
# Epoch 18/77
# 19/19 [==============================] - 5s 283ms/step - loss: 6.4265e-04 - val_loss: 8.7742e-04
# Epoch 19/77
# 19/19 [==============================] - 5s 284ms/step - loss: 6.2619e-04 - val_loss: 7.0804e-04
# Epoch 20/77
# 19/19 [==============================] - 6s 290ms/step - loss: 6.0705e-04 - val_loss: 6.8603e-04
# Epoch 21/77
# 19/19 [==============================] - 5s 280ms/step - loss: 5.8322e-04 - val_loss: 6.6421e-04
# Epoch 22/77
# 19/19 [==============================] - 5s 276ms/step - loss: 6.3662e-04 - val_loss: 6.9432e-04
# Epoch 23/77
# 19/19 [==============================] - 5s 278ms/step - loss: 6.2989e-04 - val_loss: 6.9258e-04
# Epoch 24/77
# 19/19 [==============================] - 5s 276ms/step - loss: 5.6857e-04 - val_loss: 6.1945e-04
# Epoch 25/77
# 19/19 [==============================] - 5s 281ms/step - loss: 5.4161e-04 - val_loss: 5.9417e-04
# Epoch 26/77
# 19/19 [==============================] - 5s 273ms/step - loss: 5.6125e-04 - val_loss: 5.8652e-04
# Epoch 27/77
# 19/19 [==============================] - 5s 275ms/step - loss: 5.5705e-04 - val_loss: 7.4492e-04
# Epoch 28/77
# 19/19 [==============================] - 5s 273ms/step - loss: 5.5297e-04 - val_loss: 5.5786e-04
# Epoch 29/77
# 19/19 [==============================] - 5s 275ms/step - loss: 5.6038e-04 - val_loss: 6.1274e-04
# Epoch 30/77
# 19/19 [==============================] - 5s 271ms/step - loss: 5.0181e-04 - val_loss: 5.3876e-04
# Epoch 31/77
# 19/19 [==============================] - 5s 279ms/step - loss: 4.8771e-04 - val_loss: 5.3361e-04
# Epoch 32/77
# 19/19 [==============================] - 5s 284ms/step - loss: 4.7070e-04 - val_loss: 6.3128e-04
# Epoch 33/77
# 19/19 [==============================] - 5s 278ms/step - loss: 4.7594e-04 - val_loss: 6.4898e-04
# Epoch 34/77
# 19/19 [==============================] - 5s 283ms/step - loss: 4.7460e-04 - val_loss: 4.7232e-04
# Epoch 35/77
# 19/19 [==============================] - 5s 280ms/step - loss: 4.8567e-04 - val_loss: 5.6413e-04
# Epoch 36/77
# 19/19 [==============================] - 5s 267ms/step - loss: 4.5290e-04 - val_loss: 4.4508e-04
# Epoch 37/77
# 19/19 [==============================] - 5s 270ms/step - loss: 4.6117e-04 - val_loss: 5.1336e-04
# Epoch 38/77
# 19/19 [==============================] - 5s 270ms/step - loss: 4.2005e-04 - val_loss: 5.2158e-04
# Epoch 39/77
# 19/19 [==============================] - 5s 271ms/step - loss: 4.1252e-04 - val_loss: 4.7102e-04
# Epoch 40/77
# 19/19 [==============================] - 5s 268ms/step - loss: 4.0306e-04 - val_loss: 3.8836e-04
# Epoch 41/77
# 19/19 [==============================] - 5s 272ms/step - loss: 3.9596e-04 - val_loss: 5.6468e-04
# Epoch 42/77
# 19/19 [==============================] - 5s 268ms/step - loss: 4.0743e-04 - val_loss: 3.7904e-04
# Epoch 43/77
# 19/19 [==============================] - 5s 264ms/step - loss: 3.6341e-04 - val_loss: 3.6044e-04
# Epoch 44/77
# 19/19 [==============================] - 5s 269ms/step - loss: 3.7199e-04 - val_loss: 3.6795e-04
# Epoch 45/77
# 19/19 [==============================] - 5s 265ms/step - loss: 3.5246e-04 - val_loss: 3.2726e-04
# Epoch 46/77
# 19/19 [==============================] - 5s 264ms/step - loss: 3.6745e-04 - val_loss: 3.1431e-04
# Epoch 47/77
# 19/19 [==============================] - 5s 261ms/step - loss: 3.4414e-04 - val_loss: 3.0819e-04
# Epoch 48/77
# 19/19 [==============================] - 5s 261ms/step - loss: 3.2966e-04 - val_loss: 3.4251e-04
# Epoch 49/77
# 19/19 [==============================] - 5s 265ms/step - loss: 3.3379e-04 - val_loss: 3.3873e-04
# Epoch 50/77
# 19/19 [==============================] - 5s 263ms/step - loss: 3.1212e-04 - val_loss: 2.9783e-04
# Epoch 51/77
# 19/19 [==============================] - 5s 259ms/step - loss: 3.0918e-04 - val_loss: 2.6557e-04
# Epoch 52/77
# 19/19 [==============================] - 5s 263ms/step - loss: 2.8863e-04 - val_loss: 2.7084e-04
# Epoch 53/77
# 19/19 [==============================] - 5s 261ms/step - loss: 2.9760e-04 - val_loss: 2.8754e-04
# Epoch 54/77
# 19/19 [==============================] - 5s 259ms/step - loss: 3.0261e-04 - val_loss: 2.5622e-04
# Epoch 55/77
# 19/19 [==============================] - 5s 257ms/step - loss: 2.9534e-04 - val_loss: 2.9555e-04
# Epoch 56/77
# 19/19 [==============================] - 5s 260ms/step - loss: 2.6974e-04 - val_loss: 2.3948e-04
# Epoch 57/77
# 19/19 [==============================] - 5s 261ms/step - loss: 2.5191e-04 - val_loss: 2.1953e-04
# Epoch 58/77
# 19/19 [==============================] - 5s 257ms/step - loss: 2.5135e-04 - val_loss: 2.9563e-04
# Epoch 59/77
# 19/19 [==============================] - 5s 255ms/step - loss: 3.3342e-04 - val_loss: 3.0186e-04
# Epoch 60/77
# 19/19 [==============================] - 5s 256ms/step - loss: 2.6187e-04 - val_loss: 2.2394e-04
# Epoch 61/77
# 19/19 [==============================] - 5s 261ms/step - loss: 2.4007e-04 - val_loss: 2.1749e-04
# Epoch 62/77
# 19/19 [==============================] - 5s 249ms/step - loss: 2.3744e-04 - val_loss: 2.0723e-04
# Epoch 63/77
# 19/19 [==============================] - 5s 247ms/step - loss: 2.3818e-04 - val_loss: 2.6970e-04
# Epoch 64/77
# 19/19 [==============================] - 5s 254ms/step - loss: 2.5660e-04 - val_loss: 2.1981e-04
# Epoch 65/77
# 19/19 [==============================] - 5s 256ms/step - loss: 2.2482e-04 - val_loss: 1.9822e-04
# Epoch 66/77
# 19/19 [==============================] - 5s 250ms/step - loss: 2.9892e-04 - val_loss: 2.1795e-04
# Epoch 67/77
# 19/19 [==============================] - 5s 250ms/step - loss: 2.4347e-04 - val_loss: 1.8671e-04
# Epoch 68/77
# 19/19 [==============================] - 4s 228ms/step - loss: 2.0564e-04 - val_loss: 2.1556e-04
# Epoch 69/77
# 19/19 [==============================] - 5s 248ms/step - loss: 2.0384e-04 - val_loss: 2.1015e-04
# Epoch 70/77
# 19/19 [==============================] - 5s 253ms/step - loss: 1.9416e-04 - val_loss: 2.1823e-04
# Epoch 71/77
# 19/19 [==============================] - 5s 249ms/step - loss: 1.9813e-04 - val_loss: 1.6673e-04
# Epoch 72/77
# 19/19 [==============================] - 5s 247ms/step - loss: 1.8565e-04 - val_loss: 2.0234e-04
# Epoch 73/77
# 19/19 [==============================] - 5s 246ms/step - loss: 2.0347e-04 - val_loss: 1.5277e-04
# Epoch 74/77
# 19/19 [==============================] - 5s 248ms/step - loss: 1.8006e-04 - val_loss: 1.4909e-04
# Epoch 75/77
# 19/19 [==============================] - 5s 249ms/step - loss: 1.8176e-04 - val_loss: 1.5043e-04
# Epoch 76/77
# 19/19 [==============================] - 5s 288ms/step - loss: 1.8358e-04 - val_loss: 1.4453e-04
# Epoch 77/77
# 19/19 [==============================] - 6s 290ms/step - loss: 2.2380e-04 - val_loss: 2.4811e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 42/42 [==============================] - 5s 69ms/step
# 16/16 [==============================] - 1s 70ms/step

# %%
# Reversing the MinMax Scaler as follows:
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
print(math.sqrt(mean_squared_error(y_train, train_predict)))
print(math.sqrt(mean_squared_error(y_test,test_predict)))
# Out:
# 135.81729170426993
# 209.86264489473598

# %%
### Here, We Visualising the Predictions:
look_back = 100
train_num_pyredict_plot = np.empty_like(data_close)
train_num_pyredict_plot[:, :] = np.nan
train_num_pyredict_plot[look_back : len(train_predict) + look_back, :] = train_predict
test_predict_plot = np.empty_like(data_close)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (look_back * 2) + 1 : len(data_close) - 1, :] = test_predict
plt.plot(scaler.inverse_transform(data_close))
plt.plot(train_num_pyredict_plot)
plt.plot(test_predict_plot)
plt.show()

# %% [markdown]
# Here,
# * Green indicates the predicted (test) data.
# * Orange indicates the trained data.
# * Blue indicates the complete data.

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)
len(stock)
# Out:
# 2035

# %%
### Finally, We Get The Future Prediction Model:
x_inum_pyut=test[307:].reshape(1, -1)
x_inum_pyut.shape
temp_inum_pyut = list(x_inum_pyut)
temp_inum_pyut = temp_inum_pyut[0].tolist()
temp_inum_pyut = list(x_inum_pyut)
temp_inum_pyut = temp_inum_pyut[0].tolist()

# %%
day_new = np.arange(1, 101)
day_pred = np.arange(101, 131)
plt.plot(day_new, scaler.inverse_transform(data_close[1935 : ]))
